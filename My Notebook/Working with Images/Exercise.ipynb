# %%
from PIL import Image

# %%
# Solution for png error


# For mask.png
mask = Image.open('mask.jpg')  # current file

newmask = mask.convert('RGB')           

newmask.save("newmask.jpg")          # new file

mask = Image.open('newmask.jpg')     # importing new file as mask


# For word_matrix.png
# Solution for png error

word_matrix = Image.open('word_matrix.jpg')  # current file

newword_matrix = word_matrix.convert('RGB')           

newword_matrix.save("newword_matrix.jpg")          # new file

word_matrix = Image.open('newword_matrix.jpg')     # importing new file as word_matrix

# %%
newmask
# Out:
# <PIL.Image.Image image mode=RGB size=505x251>

# %%
newmask.size
# Out:
# (505, 251)

# %%
newword_matrix
# Out:
# <PIL.Image.Image image mode=RGB size=1015x559>

# %%
newword_matrix.size
# Out:
# (1015, 559)

# %%
resized_mask = newmask.resize((1015, 559))

# %%
resized_mask
# Out:
# <PIL.Image.Image image mode=RGB size=1015x559>

# %%
resized_mask.putalpha(200)

# %%
resized_mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559>

# %%
newword_matrix.paste(im = resized_mask, box = (0,0), mask = resized_mask)

# %%
newword_matrix
# Out:
# <PIL.Image.Image image mode=RGB size=1015x559>
